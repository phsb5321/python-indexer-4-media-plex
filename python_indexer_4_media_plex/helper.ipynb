# %%
import os
from natsort import natsorted

COURSE_NAME = "Full Cycle 3.0 - School of Net"
ROOT_PATH = os.path.expanduser(f"~/Documents/Library/{COURSE_NAME}")
DESTINATION_PATH = os.path.expanduser("~/Documents/Media/Courses/")
RED_COLOR = "\033[1;31m"
GREEN_COLOR = "\033[1;32m"
END_COLOR = "\033[m"

# %%
def custom_sort_key(item):
    parts = item.split(".")  # split on the dot
    return (
        int(parts[0]) if parts[0].isdigit() else float("inf"),
        item,
    )  # sort by the first part as an int, or inf if not an int

# %%
def create_directory(directory):
    if not os.path.exists(directory):
        print(f"Creating directory: {directory}")
        os.mkdir(directory)


def create_symlink(src, dest):
    if not os.path.exists(dest):
        print(f"Creating symlink: {src} -> {dest}")
        os.symlink(src, dest)


def has_video_files_in_directory(dir_path: str) -> bool:
    """Checks if the directory contains any video files with extensions .mp4, .mkv, .mov, etc."""

    # List of common video file extensions
    video_extensions = [".mp4", ".mkv", ".mov", ".avi", ".flv", ".wmv"]

    for _, _, filenames in os.walk(dir_path):
        if any(
            filename.endswith(extension)
            for filename in filenames
            for extension in video_extensions
        ):
            return True
    return False

# %%
def process_deepest_directory(
    directory_path: str,
    items: list,
    dry_run: bool,
    indent: str,
    season_number: int,
    episode_counter: int,
) -> int:
    """Handles the logic for the deepest directory."""
    directory_name = f"Season {season_number} - {directory_path.split('/')[-1]}"

    if not dry_run:
        create_directory(os.path.join(DESTINATION_PATH, directory_name))

    print(
        f"{indent}{RED_COLOR}{directory_path.split('/')[-1]}{END_COLOR} -> {GREEN_COLOR}{directory_name}{END_COLOR}"
    )

    index = episode_counter - 1  # Initialize index

    for index, item in enumerate(
        (i for i in items if i.endswith(".mp4")), start=episode_counter
    ):
        symlink_name = f"S{season_number:02d}E{index:02d} - {item}"
        symlink_path = os.path.join(DESTINATION_PATH, directory_name, symlink_name)

        if not dry_run:
            create_symlink(os.path.join(directory_path, item), symlink_path)

        print(f"{indent}\t{item} -> {symlink_name}")

    return index

# %%
def sym_link_generator(
    directory_path: str,
    indent: str = "",
    is_deepest: bool = False,
    dry_run: bool = True,
    season_number: int = 1,
    episode_counter: int = 1,
) -> (int, int):
    # Fetches all the items in the given directory path and sorts them
    items = sorted(os.listdir(directory_path), key=custom_sort_key)

    # Check if the current directory is the deepest by seeing if it contains no other subdirectories
    is_deepest = not any(
        os.path.isdir(os.path.join(directory_path, subitem)) for subitem in items
    )

    # Base case: When the directory being processed is the deepest (contains media files, and no subdirectories)
    if is_deepest:
        # Processes the files in the directory (e.g., creating symlinks)
        episode_counter = process_deepest_directory(
            directory_path, items, dry_run, indent, season_number, episode_counter
        )
        # Increment the season number once the deepest directory has been processed
        season_number += 1

    # Iterate over items in the current directory
    for item in items:
        full_path = os.path.join(directory_path, item)

        # Checks if the current item is a directory
        if os.path.isdir(full_path):
            # If the directory does not contain .mp4 files, then skip it
            if not has_video_files_in_directory(full_path):
                continue

            # Check if the current subdirectory is the deepest by seeing if it contains no other subdirectories
            is_deepest_subdirectory = not any(
                os.path.isdir(os.path.join(full_path, subitem))
                for subitem in os.listdir(full_path)
            )

            # Recursive call: If the item is a directory, then delve deeper
            episode_counter, season_number = sym_link_generator(
                full_path,
                indent + "\t",
                is_deepest_subdirectory,
                dry_run,
                season_number,
                episode_counter,
            )

    # Return the updated episode counter and season number
    return episode_counter, season_number

# %%
def main(dry_run=True):
    global DESTINATION_PATH  # Indicate that you're using the global variable
    file_tree = natsorted(os.listdir(ROOT_PATH), key=custom_sort_key)
    if not dry_run:
        create_directory(os.path.join(DESTINATION_PATH, COURSE_NAME))
        DESTINATION_PATH = os.path.join(DESTINATION_PATH, COURSE_NAME)

    season_counter = 1
    for directory in file_tree:
        _, season_counter = sym_link_generator(
            os.path.join(ROOT_PATH, directory),
            dry_run=dry_run,
            season_number=season_counter,
        )

# %%
if __name__ == "__main__":
    main(dry_run=False)
# Out:
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 1 - 0. Repositorios
# 0. Repositorios -> Season 1 - 0. Repositorios
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 2 - 1. Primeiros passos
# 	1. Primeiros passos -> Season 2 - 1. Primeiros passos
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/1. Comece por aqui/1. Primeiros passos/1. Primeiros passos.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 2 - 1. Primeiros passos/S02E01 - 1. Primeiros passos.mp4
# 		1. Primeiros passos.mp4 -> S02E01 - 1. Primeiros passos.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/1. Comece por aqui/1. Primeiros passos/2. Teoria vs Pratica.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 2 - 1. Primeiros passos/S02E02 - 2. Teoria vs Pratica.mp4
# 		2. Teoria vs Pratica.mp4 -> S02E02 - 2. Teoria vs Pratica.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/1. Comece por aqui/1. Primeiros passos/3. Ligando os pontos.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 2 - 1. Primeiros passos/S02E03 - 3. Ligando os pontos.mp4
# 		3. Ligando os pontos.mp4 -> S02E03 - 3. Ligando os pontos.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/1. Comece por aqui/1. Primeiros passos/4. Processo de gravação e atualização.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 2 - 1. Primeiros passos/S02E04 - 4. Processo de gravação e atualização.mp4
# 		4. Processo de gravação e atualização.mp4 -> S02E04 - 4. Processo de gravação e atualização.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/1. Comece por aqui/1. Primeiros passos/5. Nos ajude a te ajudar.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 2 - 1. Primeiros passos/S02E05 - 5. Nos ajude a te ajudar.mp4
# 		5. Nos ajude a te ajudar.mp4 -> S02E05 - 5. Nos ajude a te ajudar.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero
# 	1. Começando do zero -> Season 3 - 1. Começando do zero
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/1. Introdução.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E01 - 1. Introdução.mp4
# 		1. Introdução.mp4 -> S03E01 - 1. Introdução.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/2. Instalando Docker.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E02 - 2. Instalando Docker.mp4
# 		2. Instalando Docker.mp4 -> S03E02 - 2. Instalando Docker.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/3. Conhecendo o WSL 2.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E03 - 3. Conhecendo o WSL 2.mp4
# 		3. Conhecendo o WSL 2.mp4 -> S03E03 - 3. Conhecendo o WSL 2.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/4. Instalando WSL 2 do zero.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E04 - 4. Instalando WSL 2 do zero.mp4
# 		4. Instalando WSL 2 do zero.mp4 -> S03E04 - 4. Instalando WSL 2 do zero.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/5. Dicas truques com WSL 2 e Windows Terminal.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E05 - 5. Dicas truques com WSL 2 e Windows Terminal.mp4
# 		5. Dicas truques com WSL 2 e Windows Terminal.mp4 -> S03E05 - 5. Dicas truques com WSL 2 e Windows Terminal.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/6. Backup com WSL 2.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E06 - 6. Backup com WSL 2.mp4
# 		6. Backup com WSL 2.mp4 -> S03E06 - 6. Backup com WSL 2.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/1. Começando do zero/7. Integrando Docker com WSL 2.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 3 - 1. Começando do zero/S03E07 - 7. Integrando Docker com WSL 2.mp4
# 		7. Integrando Docker com WSL 2.mp4 -> S03E07 - 7. Integrando Docker com WSL 2.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker
# 	3. Iniciando com Docker -> Season 4 - 3. Iniciando com Docker
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/1. Hello World.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E07 - 1. Hello World.mp4
# 		1. Hello World.mp4 -> S04E07 - 1. Hello World.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/2. Executando Ubuntu.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E08 - 2. Executando Ubuntu.mp4
# 		2. Executando Ubuntu.mp4 -> S04E08 - 2. Executando Ubuntu.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/3. Publicando portas com nginx.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E09 - 3. Publicando portas com nginx.mp4
# 		3. Publicando portas com nginx.mp4 -> S04E09 - 3. Publicando portas com nginx.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/4. Removendo containers.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E10 - 4. Removendo containers.mp4
# 		4. Removendo containers.mp4 -> S04E10 - 4. Removendo containers.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/5. Acessando e alterando arquivos de um container.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E11 - 5. Acessando e alterando arquivos de um container.mp4
# 		5. Acessando e alterando arquivos de um container.mp4 -> S04E11 - 5. Acessando e alterando arquivos de um container.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/6. Iniciando com bind mounts.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E12 - 6. Iniciando com bind mounts.mp4
# 		6. Iniciando com bind mounts.mp4 -> S04E12 - 6. Iniciando com bind mounts.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/3. Iniciando com Docker/7. Trabalhando com volumes.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 4 - 3. Iniciando com Docker/S04E13 - 7. Trabalhando com volumes.mp4
# 		7. Trabalhando com volumes.mp4 -> S04E13 - 7. Trabalhando com volumes.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens
# 	4. Trabalhando com imagens -> Season 5 - 4. Trabalhando com imagens
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/4. Trabalhando com imagens/1. Entendendo imagens e DockerHub.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens/S05E13 - 1. Entendendo imagens e DockerHub.mp4
# 		1. Entendendo imagens e DockerHub.mp4 -> S05E13 - 1. Entendendo imagens e DockerHub.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/4. Trabalhando com imagens/2. Criando primeira imagem com Dockerfile.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens/S05E14 - 2. Criando primeira imagem com Dockerfile.mp4
# 		2. Criando primeira imagem com Dockerfile.mp4 -> S05E14 - 2. Criando primeira imagem com Dockerfile.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/4. Trabalhando com imagens/3. Avançando com Dockerfile.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens/S05E15 - 3. Avançando com Dockerfile.mp4
# 		3. Avançando com Dockerfile.mp4 -> S05E15 - 3. Avançando com Dockerfile.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/4. Trabalhando com imagens/4. ENTRYPOINT vs CMD.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens/S05E16 - 4. ENTRYPOINT vs CMD.mp4
# 		4. ENTRYPOINT vs CMD.mp4 -> S05E16 - 4. ENTRYPOINT vs CMD.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/4. Trabalhando com imagens/5. Docker entrypoint exec.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens/S05E17 - 5. Docker entrypoint exec.mp4
# 		5. Docker entrypoint exec.mp4 -> S05E17 - 5. Docker entrypoint exec.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/4. Trabalhando com imagens/6. Publicando imagem no DockerHub.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 5 - 4. Trabalhando com imagens/S05E18 - 6. Publicando imagem no DockerHub.mp4
# 		6. Publicando imagem no DockerHub.mp4 -> S05E18 - 6. Publicando imagem no DockerHub.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 6 - 5. Networks
# 	5. Networks -> Season 6 - 5. Networks
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/5. Networks/1. Entendento tipos de Network.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 6 - 5. Networks/S06E18 - 1. Entendento tipos de Network.mp4
# 		1. Entendento tipos de Network.mp4 -> S06E18 - 1. Entendento tipos de Network.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/5. Networks/2. Trabalhando com bridge.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 6 - 5. Networks/S06E19 - 2. Trabalhando com bridge.mp4
# 		2. Trabalhando com bridge.mp4 -> S06E19 - 2. Trabalhando com bridge.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/5. Networks/3. Trabalhando com host.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 6 - 5. Networks/S06E20 - 3. Trabalhando com host.mp4
# 		3. Trabalhando com host.mp4 -> S06E20 - 3. Trabalhando com host.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/5. Networks/4. Container acessando nossa maquina.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 6 - 5. Networks/S06E21 - 4. Container acessando nossa maquina.mp4
# 		4. Container acessando nossa maquina.mp4 -> S06E21 - 4. Container acessando nossa maquina.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 7 - 6. Colocando em prática
# 	6. Colocando em prática -> Season 7 - 6. Colocando em prática
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/6. Colocando em prática/1. Instalando framework em um container.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 7 - 6. Colocando em prática/S07E21 - 1. Instalando framework em um container.mp4
# 		1. Instalando framework em um container.mp4 -> S07E21 - 1. Instalando framework em um container.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/6. Colocando em prática/2. Ativando entrypoint e command.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 7 - 6. Colocando em prática/S07E22 - 2. Ativando entrypoint e command.mp4
# 		2. Ativando entrypoint e command.mp4 -> S07E22 - 2. Ativando entrypoint e command.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/6. Colocando em prática/3. Criando aplicação Node.js sem o Node.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 7 - 6. Colocando em prática/S07E23 - 3. Criando aplicação Node.js sem o Node.mp4
# 		3. Criando aplicação Node.js sem o Node.mp4 -> S07E23 - 3. Criando aplicação Node.js sem o Node.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/6. Colocando em prática/4. Gerando imagem da aplicação Node.js.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 7 - 6. Colocando em prática/S07E24 - 4. Gerando imagem da aplicação Node.js.mp4
# 		4. Gerando imagem da aplicação Node.js.mp4 -> S07E24 - 4. Gerando imagem da aplicação Node.js.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 8 - 7. Otimizando imagens
# 	7. Otimizando imagens -> Season 8 - 7. Otimizando imagens
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/7. Otimizando imagens/1. Otimização utilizando Multistage Building.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 8 - 7. Otimizando imagens/S08E24 - 1. Otimização utilizando Multistage Building.mp4
# 		1. Otimização utilizando Multistage Building.mp4 -> S08E24 - 1. Otimização utilizando Multistage Building.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/7. Otimizando imagens/2. Nginx como proxy reverso.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 8 - 7. Otimizando imagens/S08E25 - 2. Nginx como proxy reverso.mp4
# 		2. Nginx como proxy reverso.mp4 -> S08E25 - 2. Nginx como proxy reverso.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose
# 	8. Docker-compose -> Season 9 - 8. Docker-compose
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/8. Docker-compose/1. Iniciando com Docker-compose.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose/S09E25 - 1. Iniciando com Docker-compose.mp4
# 		1. Iniciando com Docker-compose.mp4 -> S09E25 - 1. Iniciando com Docker-compose.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/8. Docker-compose/2. Buildando images com Docker-compose.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose/S09E26 - 2. Buildando images com Docker-compose.mp4
# 		2. Buildando images com Docker-compose.mp4 -> S09E26 - 2. Buildando images com Docker-compose.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/8. Docker-compose/3. Criando banco de dados MySQL.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose/S09E27 - 3. Criando banco de dados MySQL.mp4
# 		3. Criando banco de dados MySQL.mp4 -> S09E27 - 3. Criando banco de dados MySQL.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/8. Docker-compose/4. Configurando app node com docker-compose.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose/S09E28 - 4. Configurando app node com docker-compose.mp4
# 		4. Configurando app node com docker-compose.mp4 -> S09E28 - 4. Configurando app node com docker-compose.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/8. Docker-compose/6. Node vs MySQL.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose/S09E29 - 6. Node vs MySQL.mp4
# 		6. Node vs MySQL.mp4 -> S09E29 - 6. Node vs MySQL.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/8. Docker-compose/7. Dependência entre containers.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 9 - 8. Docker-compose/S09E30 - 7. Dependência entre containers.mp4
# 		7. Dependência entre containers.mp4 -> S09E30 - 7. Dependência entre containers.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 10 - 9. Desafio
# 	9. Desafio -> Season 10 - 9. Desafio
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/2. Docker/9. Desafio/1. Desafio.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 10 - 9. Desafio/S10E30 - 1. Desafio.mp4
# 		1. Desafio.mp4 -> S10E30 - 1. Desafio.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 11 - 1. Introdução
# 	1. Introdução -> Season 11 - 1. Introdução
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/1. Introdução/1. Introdução.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 11 - 1. Introdução/S11E01 - 1. Introdução.mp4
# 		1. Introdução.mp4 -> S11E01 - 1. Introdução.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 12 - 2. Iniciando com Gitflow
# 	2. Iniciando com Gitflow -> Season 12 - 2. Iniciando com Gitflow
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/2. Iniciando com Gitflow/1. Introdução ao Gitflow.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 12 - 2. Iniciando com Gitflow/S12E01 - 1. Introdução ao Gitflow.mp4
# 		1. Introdução ao Gitflow.mp4 -> S12E01 - 1. Introdução ao Gitflow.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/2. Iniciando com Gitflow/3. Mão na massa.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 12 - 2. Iniciando com Gitflow/S12E02 - 3. Mão na massa.mp4
# 		3. Mão na massa.mp4 -> S12E02 - 3. Mão na massa.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 13 - 3. Assinatura de commits
# 	3. Assinatura de commits -> Season 13 - 3. Assinatura de commits
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/3. Assinatura de commits/1. Entendendo sobre assinaturas.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 13 - 3. Assinatura de commits/S13E02 - 1. Entendendo sobre assinaturas.mp4
# 		1. Entendendo sobre assinaturas.mp4 -> S13E02 - 1. Entendendo sobre assinaturas.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/3. Assinatura de commits/2. Gerando chave gpg e assinando commits.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 13 - 3. Assinatura de commits/S13E03 - 2. Gerando chave gpg e assinando commits.mp4
# 		2. Gerando chave gpg e assinando commits.mp4 -> S13E03 - 2. Gerando chave gpg e assinando commits.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/3. Assinatura de commits/3. Adicionando outro email na chave.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 13 - 3. Assinatura de commits/S13E04 - 3. Adicionando outro email na chave.mp4
# 		3. Adicionando outro email na chave.mp4 -> S13E04 - 3. Adicionando outro email na chave.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review
# 	4. PRs e Code Review -> Season 14 - 4. PRs e Code Review
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/1. Protegendo branches.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E04 - 1. Protegendo branches.mp4
# 		1. Protegendo branches.mp4 -> S14E04 - 1. Protegendo branches.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/3. Criando nossa primeira PR.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E05 - 3. Criando nossa primeira PR.mp4
# 		3. Criando nossa primeira PR.mp4 -> S14E05 - 3. Criando nossa primeira PR.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/4. Criando template para PRs.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E06 - 4. Criando template para PRs.mp4
# 		4. Criando template para PRs.mp4 -> S14E06 - 4. Criando template para PRs.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/5. Iniciando com Code Review.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E07 - 5. Iniciando com Code Review.mp4
# 		5. Iniciando com Code Review.mp4 -> S14E07 - 5. Iniciando com Code Review.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/6. Protegendo branch para Code Review.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E08 - 6. Protegendo branch para Code Review.mp4
# 		6. Protegendo branch para Code Review.mp4 -> S14E08 - 6. Protegendo branch para Code Review.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/7. Trabalhando com CODEOWNERS.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E09 - 7. Trabalhando com CODEOWNERS.mp4
# 		7. Trabalhando com CODEOWNERS.mp4 -> S14E09 - 7. Trabalhando com CODEOWNERS.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/4. PRs e Code Review/8. Extensão do Github para o VSCode.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 14 - 4. PRs e Code Review/S14E10 - 8. Extensão do Github para o VSCode.mp4
# 		8. Extensão do Github para o VSCode.mp4 -> S14E10 - 8. Extensão do Github para o VSCode.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits
# 	5. SemVer e Conventional Commits -> Season 15 - 5. SemVer e Conventional Commits
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/5. SemVer e Conventional Commits/1. Semantical versioning.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits/S15E10 - 1. Semantical versioning.mp4
# 		1. Semantical versioning.mp4 -> S15E10 - 1. Semantical versioning.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/5. SemVer e Conventional Commits/2. Conventional commits.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits/S15E11 - 2. Conventional commits.mp4
# 		2. Conventional commits.mp4 -> S15E11 - 2. Conventional commits.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/5. SemVer e Conventional Commits/3. Conventional no VSCode.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits/S15E12 - 3. Conventional no VSCode.mp4
# 		3. Conventional no VSCode.mp4 -> S15E12 - 3. Conventional no VSCode.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/5. SemVer e Conventional Commits/4. Trabalhando com commitlint.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits/S15E13 - 4. Trabalhando com commitlint.mp4
# 		4. Trabalhando com commitlint.mp4 -> S15E13 - 4. Trabalhando com commitlint.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/5. SemVer e Conventional Commits/5. Checando padrões de commit com commitsar.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits/S15E14 - 5. Checando padrões de commit com commitsar.mp4
# 		5. Checando padrões de commit com commitsar.mp4 -> S15E14 - 5. Checando padrões de commit com commitsar.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/3. Padrões e técnicas avançadas com Git e Github/5. SemVer e Conventional Commits/6. Commitando com Commitizen.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 15 - 5. SemVer e Conventional Commits/S15E15 - 6. Commitando com Commitizen.mp4
# 		6. Commitando com Commitizen.mp4 -> S15E15 - 6. Commitando com Commitizen.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 16 - 1. Introdução
# 	1. Introdução -> Season 16 - 1. Introdução
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/1. Introdução/1. Iniciando com Integração contínua.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 16 - 1. Introdução/S16E01 - 1. Iniciando com Integração contínua.mp4
# 		1. Iniciando com Integração contínua.mp4 -> S16E01 - 1. Iniciando com Integração contínua.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 17 - 3. Iniciando com CI
# 	3. Iniciando com CI -> Season 17 - 3. Iniciando com CI
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/3. Iniciando com CI/1. Criando software exemplo.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 17 - 3. Iniciando com CI/S17E01 - 1. Criando software exemplo.mp4
# 		1. Criando software exemplo.mp4 -> S17E01 - 1. Criando software exemplo.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/3. Iniciando com CI/2. Criando primeiro workflow.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 17 - 3. Iniciando com CI/S17E02 - 2. Criando primeiro workflow.mp4
# 		2. Criando primeiro workflow.mp4 -> S17E02 - 2. Criando primeiro workflow.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/3. Iniciando com CI/3. Fazendo github actions não passar.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 17 - 3. Iniciando com CI/S17E03 - 3. Fazendo github actions não passar.mp4
# 		3. Fazendo github actions não passar.mp4 -> S17E03 - 3. Fazendo github actions não passar.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/3. Iniciando com CI/4. Ativando status check.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 17 - 3. Iniciando com CI/S17E04 - 4. Ativando status check.mp4
# 		4. Ativando status check.mp4 -> S17E04 - 4. Ativando status check.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/3. Iniciando com CI/5. Trabalhando com Strategy Matrix.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 17 - 3. Iniciando com CI/S17E05 - 5. Trabalhando com Strategy Matrix.mp4
# 		5. Trabalhando com Strategy Matrix.mp4 -> S17E05 - 5. Trabalhando com Strategy Matrix.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 18 - 4. CI com Docker
# 	4. CI com Docker -> Season 18 - 4. CI com Docker
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/4. CI com Docker/1. Criando Dockerfile.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 18 - 4. CI com Docker/S18E05 - 1. Criando Dockerfile.mp4
# 		1. Criando Dockerfile.mp4 -> S18E05 - 1. Criando Dockerfile.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/4. CI com Docker/3. Gerando build da imagem via CI.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 18 - 4. CI com Docker/S18E06 - 3. Gerando build da imagem via CI.mp4
# 		3. Gerando build da imagem via CI.mp4 -> S18E06 - 3. Gerando build da imagem via CI.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/4. CI com Docker/4. Dando push na imagem automaticamente.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 18 - 4. CI com Docker/S18E07 - 4. Dando push na imagem automaticamente.mp4
# 		4. Dando push na imagem automaticamente.mp4 -> S18E07 - 4. Dando push na imagem automaticamente.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube
# 	5. Sonarqube -> Season 19 - 5. Sonarqube
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/1. Iniciando com Sonarqube.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E07 - 1. Iniciando com Sonarqube.mp4
# 		1. Iniciando com Sonarqube.mp4 -> S19E07 - 1. Iniciando com Sonarqube.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/2. Conceitos principais.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E08 - 2. Conceitos principais.mp4
# 		2. Conceitos principais.mp4 -> S19E08 - 2. Conceitos principais.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/3. Instalando primeiro projeto.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E09 - 3. Instalando primeiro projeto.mp4
# 		3. Instalando primeiro projeto.mp4 -> S19E09 - 3. Instalando primeiro projeto.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/4. Trabalhando com cobertura de código.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E10 - 4. Trabalhando com cobertura de código.mp4
# 		4. Trabalhando com cobertura de código.mp4 -> S19E10 - 4. Trabalhando com cobertura de código.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/5. Cobrindo código Javascript.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E11 - 5. Cobrindo código Javascript.mp4
# 		5. Cobrindo código Javascript.mp4 -> S19E11 - 5. Cobrindo código Javascript.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/6. Preparando ambiente para o SonarCloud.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E12 - 6. Preparando ambiente para o SonarCloud.mp4
# 		6. Preparando ambiente para o SonarCloud.mp4 -> S19E12 - 6. Preparando ambiente para o SonarCloud.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/7. Executando SonarCloud.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E13 - 7. Executando SonarCloud.mp4
# 		7. Executando SonarCloud.mp4 -> S19E13 - 7. Executando SonarCloud.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/4. Integração contínua/5. Sonarqube/8. Trocando de Quality Gate.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 19 - 5. Sonarqube/S19E14 - 8. Trocando de Quality Gate.mp4
# 		8. Trocando de Quality Gate.mp4 -> S19E14 - 8. Trocando de Quality Gate.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 20 - 2. Iniciando com Kubernetes
# 	2. Iniciando com Kubernetes -> Season 20 - 2. Iniciando com Kubernetes
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/2. Iniciando com Kubernetes/1. Introdução ao Kubernetes.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 20 - 2. Iniciando com Kubernetes/S20E01 - 1. Introdução ao Kubernetes.mp4
# 		1. Introdução ao Kubernetes.mp4 -> S20E01 - 1. Introdução ao Kubernetes.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/2. Iniciando com Kubernetes/2. Instalando Kind.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 20 - 2. Iniciando com Kubernetes/S20E02 - 2. Instalando Kind.mp4
# 		2. Instalando Kind.mp4 -> S20E02 - 2. Instalando Kind.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/2. Iniciando com Kubernetes/3. Criando primeiro cluster com Kind.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 20 - 2. Iniciando com Kubernetes/S20E03 - 3. Criando primeiro cluster com Kind.mp4
# 		3. Criando primeiro cluster com Kind.mp4 -> S20E03 - 3. Criando primeiro cluster com Kind.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/2. Iniciando com Kubernetes/4. Criando cluster multi node.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 20 - 2. Iniciando com Kubernetes/S20E04 - 4. Criando cluster multi node.mp4
# 		4. Criando cluster multi node.mp4 -> S20E04 - 4. Criando cluster multi node.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/2. Iniciando com Kubernetes/5. Mudança  de contexto e extensão do VSCod.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 20 - 2. Iniciando com Kubernetes/S20E05 - 5. Mudança  de contexto e extensão do VSCod.mp4
# 		5. Mudança  de contexto e extensão do VSCod.mp4 -> S20E05 - 5. Mudança  de contexto e extensão do VSCod.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática
# 	3. Primeiros passos na prática -> Season 21 - 3. Primeiros passos na prática
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/3. Primeiros passos na prática/1. Criando aplicação exemplo e imagem.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática/S21E05 - 1. Criando aplicação exemplo e imagem.mp4
# 		1. Criando aplicação exemplo e imagem.mp4 -> S21E05 - 1. Criando aplicação exemplo e imagem.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/3. Primeiros passos na prática/2. Trabalhando com Pods.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática/S21E06 - 2. Trabalhando com Pods.mp4
# 		2. Trabalhando com Pods.mp4 -> S21E06 - 2. Trabalhando com Pods.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/3. Primeiros passos na prática/3. Criando primeira ReplicaSet.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática/S21E07 - 3. Criando primeira ReplicaSet.mp4
# 		3. Criando primeira ReplicaSet.mp4 -> S21E07 - 3. Criando primeira ReplicaSet.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/3. Primeiros passos na prática/4. O problema do ReplicaSet.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática/S21E08 - 4. O problema do ReplicaSet.mp4
# 		4. O problema do ReplicaSet.mp4 -> S21E08 - 4. O problema do ReplicaSet.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/3. Primeiros passos na prática/5. Implementando Deployment.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática/S21E09 - 5. Implementando Deployment.mp4
# 		5. Implementando Deployment.mp4 -> S21E09 - 5. Implementando Deployment.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/3. Primeiros passos na prática/6. Rollout e Revisões.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 21 - 3. Primeiros passos na prática/S21E10 - 6. Rollout e Revisões.mp4
# 		6. Rollout e Revisões.mp4 -> S21E10 - 6. Rollout e Revisões.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services
# 	4. Services -> Season 22 - 4. Services
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/4. Services/1. Entendendo o conceito de services.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services/S22E10 - 1. Entendendo o conceito de services.mp4
# 		1. Entendendo o conceito de services.mp4 -> S22E10 - 1. Entendendo o conceito de services.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/4. Services/2. Utilizando ClusterIP.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services/S22E11 - 2. Utilizando ClusterIP.mp4
# 		2. Utilizando ClusterIP.mp4 -> S22E11 - 2. Utilizando ClusterIP.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/4. Services/3. Diferenças entre Port e targetPort.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services/S22E12 - 3. Diferenças entre Port e targetPort.mp4
# 		3. Diferenças entre Port e targetPort.mp4 -> S22E12 - 3. Diferenças entre Port e targetPort.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/4. Services/4. Utilizando proxy para acessar API do Kubernetes.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services/S22E13 - 4. Utilizando proxy para acessar API do Kubernetes.mp4
# 		4. Utilizando proxy para acessar API do Kubernetes.mp4 -> S22E13 - 4. Utilizando proxy para acessar API do Kubernetes.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/4. Services/5. Utilizando NodePort.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services/S22E14 - 5. Utilizando NodePort.mp4
# 		5. Utilizando NodePort.mp4 -> S22E14 - 5. Utilizando NodePort.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/4. Services/6. Trabalhando com LoadBalancer.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 22 - 4. Services/S22E15 - 6. Trabalhando com LoadBalancer.mp4
# 		6. Trabalhando com LoadBalancer.mp4 -> S22E15 - 6. Trabalhando com LoadBalancer.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 23 - 5. Objetos de configuração
# 	5. Objetos de configuração -> Season 23 - 5. Objetos de configuração
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/5. Objetos de configuração/1. Entendendo objetos de configuração.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 23 - 5. Objetos de configuração/S23E15 - 1. Entendendo objetos de configuração.mp4
# 		1. Entendendo objetos de configuração.mp4 -> S23E15 - 1. Entendendo objetos de configuração.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/5. Objetos de configuração/2. Utilizando variáveis de ambiente.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 23 - 5. Objetos de configuração/S23E16 - 2. Utilizando variáveis de ambiente.mp4
# 		2. Utilizando variáveis de ambiente.mp4 -> S23E16 - 2. Utilizando variáveis de ambiente.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/5. Objetos de configuração/3. Variáveis de ambiente com ConfigMap.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 23 - 5. Objetos de configuração/S23E17 - 3. Variáveis de ambiente com ConfigMap.mp4
# 		3. Variáveis de ambiente com ConfigMap.mp4 -> S23E17 - 3. Variáveis de ambiente com ConfigMap.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/5. Objetos de configuração/4. Injetando ConfigMap na aplicação.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 23 - 5. Objetos de configuração/S23E18 - 4. Injetando ConfigMap na aplicação.mp4
# 		4. Injetando ConfigMap na aplicação.mp4 -> S23E18 - 4. Injetando ConfigMap na aplicação.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/5. Objetos de configuração/5. Secrets e variáveis de ambiente.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 23 - 5. Objetos de configuração/S23E19 - 5. Secrets e variáveis de ambiente.mp4
# 		5. Secrets e variáveis de ambiente.mp4 -> S23E19 - 5. Secrets e variáveis de ambiente.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes
# 	6. Probes -> Season 24 - 6. Probes
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/6. Probes/1. Entendendo health check.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes/S24E19 - 1. Entendendo health check.mp4
# 		1. Entendendo health check.mp4 -> S24E19 - 1. Entendendo health check.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/6. Probes/2. Criando endpoint Healthz.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes/S24E20 - 2. Criando endpoint Healthz.mp4
# 		2. Criando endpoint Healthz.mp4 -> S24E20 - 2. Criando endpoint Healthz.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/6. Probes/3. Liveness na prática.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes/S24E21 - 3. Liveness na prática.mp4
# 		3. Liveness na prática.mp4 -> S24E21 - 3. Liveness na prática.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/6. Probes/4. Entendendo readiness.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes/S24E22 - 4. Entendendo readiness.mp4
# 		4. Entendendo readiness.mp4 -> S24E22 - 4. Entendendo readiness.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/6. Probes/5. Combinando Liveness e Readiness.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes/S24E23 - 5. Combinando Liveness e Readiness.mp4
# 		5. Combinando Liveness e Readiness.mp4 -> S24E23 - 5. Combinando Liveness e Readiness.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/6. Probes/6. Trabalhando com startupProbe.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 24 - 6. Probes/S24E24 - 6. Trabalhando com startupProbe.mp4
# 		6. Trabalhando com startupProbe.mp4 -> S24E24 - 6. Trabalhando com startupProbe.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 25 - 7. Resources e HPA
# 	7. Resources e HPA -> Season 25 - 7. Resources e HPA
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/7. Resources e HPA/1. Instalando metrics-server.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 25 - 7. Resources e HPA/S25E24 - 1. Instalando metrics-server.mp4
# 		1. Instalando metrics-server.mp4 -> S25E24 - 1. Instalando metrics-server.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/5. Kubernetes/7. Resources e HPA/2. Entendendo utilização  de Resources.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 25 - 7. Resources e HPA/S25E25 - 2. Entendendo utilização  de Resources.mp4
# ...
# 		15. Trabalhar com datasets.mp4 -> S276E60 - 15. Trabalhar com datasets.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/9. Infra/16. Isolar datasets.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 276 - 9. Infra/S276E61 - 16. Isolar datasets.mp4
# 		16. Isolar datasets.mp4 -> S276E61 - 16. Isolar datasets.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/9. Infra/17. Teste de integração do caso de uso de recuperar categoria.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 276 - 9. Infra/S276E62 - 17. Teste de integração do caso de uso de recuperar categoria.mp4
# 		17. Teste de integração do caso de uso de recuperar categoria.mp4 -> S276E62 - 17. Teste de integração do caso de uso de recuperar categoria.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/9. Infra/18. Testando manualmente o elasticsearch e corrigindo bugs.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 276 - 9. Infra/S276E63 - 18. Testando manualmente o elasticsearch e corrigindo bugs.mp4
# 		18. Testando manualmente o elasticsearch e corrigindo bugs.mp4 -> S276E63 - 18. Testando manualmente o elasticsearch e corrigindo bugs.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 277 - 10. GraphQL
# 	10. GraphQL -> Season 277 - 10. GraphQL
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/10. GraphQL/1. Boas-vindas ao módulo de graphql na prática.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 277 - 10. GraphQL/S277E63 - 1. Boas-vindas ao módulo de graphql na prática.mp4
# 		1. Boas-vindas ao módulo de graphql na prática.mp4 -> S277E63 - 1. Boas-vindas ao módulo de graphql na prática.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/10. GraphQL/2. Criando types no graphql.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 277 - 10. GraphQL/S277E64 - 2. Criando types no graphql.mp4
# 		2. Criando types no graphql.mp4 -> S277E64 - 2. Criando types no graphql.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/10. GraphQL/3. Criando query de listar categorias com graphql.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 277 - 10. GraphQL/S277E65 - 3. Criando query de listar categorias com graphql.mp4
# 		3. Criando query de listar categorias com graphql.mp4 -> S277E65 - 3. Criando query de listar categorias com graphql.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/10. GraphQL/4. Testando graphql com client do postman.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 277 - 10. GraphQL/S277E66 - 4. Testando graphql com client do postman.mp4
# 		4. Testando graphql com client do postman.mp4 -> S277E66 - 4. Testando graphql com client do postman.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/10. GraphQL/5. Criando query de listar categoria com graphql.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 277 - 10. GraphQL/S277E67 - 5. Criando query de listar categoria com graphql.mp4
# 		5. Criando query de listar categoria com graphql.mp4 -> S277E67 - 5. Criando query de listar categoria com graphql.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 278 - 11. API Rest
# 	11. API Rest -> Season 278 - 11. API Rest
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/11. API Rest/1. Api de categorias listar.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 278 - 11. API Rest/S278E67 - 1. Api de categorias listar.mp4
# 		1. Api de categorias listar.mp4 -> S278E67 - 1. Api de categorias listar.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/11. API Rest/2. Api listar categoria pelo id.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 278 - 11. API Rest/S278E68 - 2. Api listar categoria pelo id.mp4
# 		2. Api listar categoria pelo id.mp4 -> S278E68 - 2. Api listar categoria pelo id.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/11. API Rest/3. Interceptar handlers de exceptions.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 278 - 11. API Rest/S278E69 - 3. Interceptar handlers de exceptions.mp4
# 		3. Interceptar handlers de exceptions.mp4 -> S278E69 - 3. Interceptar handlers de exceptions.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 279 - 12. CLI
# 	12. CLI -> Season 279 - 12. CLI
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/12. CLI/1. O que vamos fazer neste capítulo.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 279 - 12. CLI/S279E69 - 1. O que vamos fazer neste capítulo.mp4
# 		1. O que vamos fazer neste capítulo.mp4 -> S279E69 - 1. O que vamos fazer neste capítulo.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/12. CLI/2. Exportar dados do elasticsearch para a base de testes.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 279 - 12. CLI/S279E70 - 2. Exportar dados do elasticsearch para a base de testes.mp4
# 		2. Exportar dados do elasticsearch para a base de testes.mp4 -> S279E70 - 2. Exportar dados do elasticsearch para a base de testes.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/12. CLI/3. Mudar a interface do elaticsearch para criar índices.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 279 - 12. CLI/S279E71 - 3. Mudar a interface do elaticsearch para criar índices.mp4
# 		3. Mudar a interface do elaticsearch para criar índices.mp4 -> S279E71 - 3. Mudar a interface do elaticsearch para criar índices.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/39. Microsserviço - API do Catálogo com PHP ( Back-end )/12. CLI/4. Importar dados da base de testes para o elasticsearch.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 279 - 12. CLI/S279E72 - 4. Importar dados da base de testes para o elasticsearch.mp4
# 		4. Importar dados da base de testes para o elasticsearch.mp4 -> S279E72 - 4. Importar dados da base de testes para o elasticsearch.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 280 - 1. Introdução ao OAuth 2 e OpenID Connect
# 			1. Introdução ao OAuth 2 e OpenID Connect -> Season 280 - 1. Introdução ao OAuth 2 e OpenID Connect
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/1. Introdução ao OAuth 2 e OpenID Connect/1. Visão geral do módulo.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 280 - 1. Introdução ao OAuth 2 e OpenID Connect/S280E01 - 1. Visão geral do módulo.mp4
# 				1. Visão geral do módulo.mp4 -> S280E01 - 1. Visão geral do módulo.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/1. Introdução ao OAuth 2 e OpenID Connect/2. Conceitos básicos sobre oauth.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 280 - 1. Introdução ao OAuth 2 e OpenID Connect/S280E02 - 2. Conceitos básicos sobre oauth.mp4
# 				2. Conceitos básicos sobre oauth.mp4 -> S280E02 - 2. Conceitos básicos sobre oauth.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/1. Introdução ao OAuth 2 e OpenID Connect/3. Openid Connect.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 280 - 1. Introdução ao OAuth 2 e OpenID Connect/S280E03 - 3. Openid Connect.mp4
# 				3. Openid Connect.mp4 -> S280E03 - 3. Openid Connect.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak
# 			2. Iniciando com Keycloak -> Season 281 - 2. Iniciando com Keycloak
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/1. Iniciando com keycloak.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E03 - 1. Iniciando com keycloak.mp4
# 				1. Iniciando com keycloak.mp4 -> S281E03 - 1. Iniciando com keycloak.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/2. Criando nosso primeiro client.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E04 - 2. Criando nosso primeiro client.mp4
# 				2. Criando nosso primeiro client.mp4 -> S281E04 - 2. Criando nosso primeiro client.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/3. Gerando nosso primeiro access token.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E05 - 3. Gerando nosso primeiro access token.mp4
# 				3. Gerando nosso primeiro access token.mp4 -> S281E05 - 3. Gerando nosso primeiro access token.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/4. Gerando IDToken.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E06 - 4. Gerando IDToken.mp4
# 				4. Gerando IDToken.mp4 -> S281E06 - 4. Gerando IDToken.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/5. Mapeando atributos de usuários.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E07 - 5. Mapeando atributos de usuários.mp4
# 				5. Mapeando atributos de usuários.mp4 -> S281E07 - 5. Mapeando atributos de usuários.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/6. Trabalhando com roles.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E08 - 6. Trabalhando com roles.mp4
# 				6. Trabalhando com roles.mp4 -> S281E08 - 6. Trabalhando com roles.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/7. Trabalhando com grupos.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E09 - 7. Trabalhando com grupos.mp4
# 				7. Trabalhando com grupos.mp4 -> S281E09 - 7. Trabalhando com grupos.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/8. Autenticando utilizando github.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E10 - 8. Autenticando utilizando github.mp4
# 				8. Autenticando utilizando github.mp4 -> S281E10 - 8. Autenticando utilizando github.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/2. Iniciando com Keycloak/9. Registro usuário e consentimento de usuários.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 281 - 2. Iniciando com Keycloak/S281E11 - 9. Registro usuário e consentimento de usuários.mp4
# 				9. Registro usuário e consentimento de usuários.mp4 -> S281E11 - 9. Registro usuário e consentimento de usuários.mp4
# Creating directory: /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 282 - 3. Trabalhando com temas
# 			3. Trabalhando com temas -> Season 282 - 3. Trabalhando com temas
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/3. Trabalhando com temas/1. Keycloak com docker compose.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 282 - 3. Trabalhando com temas/S282E11 - 1. Keycloak com docker compose.mp4
# 				1. Keycloak com docker compose.mp4 -> S282E11 - 1. Keycloak com docker compose.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/3. Trabalhando com temas/2. Entendendo localização dos temas.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 282 - 3. Trabalhando com temas/S282E12 - 2. Entendendo localização dos temas.mp4
# 				2. Entendendo localização dos temas.mp4 -> S282E12 - 2. Entendendo localização dos temas.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/3. Trabalhando com temas/3. Alterando tema no keycloak e visualizando arquivos.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 282 - 3. Trabalhando com temas/S282E13 - 3. Alterando tema no keycloak e visualizando arquivos.mp4
# 				3. Alterando tema no keycloak e visualizando arquivos.mp4 -> S282E13 - 3. Alterando tema no keycloak e visualizando arquivos.mp4
# Creating symlink: /home/ubunto-notroot/Documents/Library/Full Cycle 3.0 - School of Net/Extras/Antigos/28. AutenticaÇão e Keycloak - OLD/3. Trabalhando com temas/4. Utilizando template base como exemplo.mp4 -> /home/ubunto-notroot/Documents/Media/Courses/Full Cycle 3.0 - School of Net/Season 282 - 3. Trabalhando com temas/S282E14 - 4. Utilizando template base como exemplo.mp4
# 				4. Utilizando template base como exemplo.mp4 -> S282E14 - 4. Utilizando template base como exemplo.mp4
